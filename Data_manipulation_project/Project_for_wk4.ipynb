# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
#from matplotlib import pylab as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows',100)

df=pd.read_csv("cleaned_googleplaystore.csv")
df.head(2)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1  U Launcher Lite – FREE Live Cool Themes, Hide ...
#
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0     10000  Free    0.0
# 1  ART_AND_DESIGN     4.7    87510   8.7   5000000  Free    0.0
#
#   Content Rating        Genres
# 0       Everyone  Art & Design
# 1       Everyone  Art & Design

# %% [markdown]
# ## Project for week 4

# %% [markdown]
# 1-Find if there is a correlation between the price of the apps
# and the Content Rating (Teen, Everyone, Mature. etc).

# %%
df['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults Only 18+', 'Unrated'], dtype=object)

# %%
pd.concat([df['Price'], df[result]]).head(100)

# %%
#df.groupby('Content Rating')

# %%
df[['Category','Content Rating','Type','Price']].query("Type=='Paid'").groupby('Content Rating').agg('mean')
# Out:
#                     Price
# Content Rating
# Everyone        14.900214
# Everyone 10+     4.506452
# Mature 17+       6.476667
# Teen            13.907556

# %%
result = df['Content Rating'].isin(['Teen', 'Everyone', 'Mature'])
df[result]
# Out:
#       Unnamed: 0                                                App  \
# 0              0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1              1  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 2              2                              Sketch - Draw & Paint
# 3              3              Pixel Draw - Number Art Coloring Book
# 4              4                         Paper flowers instructions
# ...          ...                                                ...
# 8191        8191                                        Chemin (fr)
# 8192        8192                                      FR Calculator
# 8193        8193                                   Sya9a Maroc - FR
# 8194        8194                   Fr. Mike Schmitz Audio Teachings
# 8196        8196      iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews       Size  Installs  Type  Price  \
# ...

# %%
df[['Category','Content Rating','Type','Price']].query("Type =='Paid'").groupby('Content Rating').agg('mean')
# Out:
#                     Price
# Content Rating
# Everyone        14.900214
# Everyone 10+     4.506452
# Mature 17+       6.476667
# Teen            13.907556

# %%
df[['Category','Content Rating','Type','Price']].query("Type=='Paid'").groupby('Content Rating').agg('mean')
# Out:
#                     Price
# Content Rating
# Everyone        14.900214
# Everyone 10+     4.506452
# Mature 17+       6.476667
# Teen            13.907556

# %%
pd.get_dummies(df[result]).tail(100)

# %%
pd.concat([df['Price'], pd.get_dummies(df.loc[result, ['Price', 'App']])], axis=1).corr()
# Out:
#                                                        Price     Price  \
# Price                                               1.000000  1.000000
# Price                                               1.000000  1.000000
# App_+Download 4 Instagram Twitter                  -0.000720 -0.000720
# App_.R                                             -0.000720 -0.000720
# App_058.ba                                         -0.000720 -0.000720
# ...                                                      ...       ...
# App_감성학원 BL 첫사랑                                    -0.000720 -0.000720
# App_💎 I'm rich                                      0.261563  0.261563
# App_💘 WhatsLov: Smileys of love, stickers and GIF  -0.000720 -0.000720
# App_📏 Smart Ruler ↔️ cm/inch measuring for home... -0.000720 -0.000720
# App_🔥 Football Wallpapers 4K | Full HD Backgrou... -0.000720 -0.000720
#
#                                                     App_+Download 4 Instagram Twitter  \
# ...

# %%
# Unique Categories in the DataFrame
df["Category"].unique()

# %%
#Summing all the numerical category
df.groupby("Category").sum()

# %%
#Total number of installs for each categories
sumed_categories = df.groupby(["Category"]).agg({"Installs":"sum"})
sumed_categories

# %%
sumed_categories.plot(kind="bar", title='Categories and Total installation', xlabel='Categories', ylabel='Total installations')

# %%
((df[['Category', 'Installs']].groupby(['Category'], sort=True)['Installs'].agg('sum'))/1000000).plot(kind='bar', title='Installs vs. Categories', xlabel="Category", ylabel='Number of Installs in Millions')

# %%
# Total numbers of installations of all the categories
df["Installs"].sum()

# %%
plt.style.use('fivethirtyeight')
plt.bar(['Category','Installs'], color='b', label='instal')
plt.title("installations Graph")
plt.xlabel("Categories")
plt.ylabel("Installs")
#plt.plot(['Category','sumed_categories'], linestyle='--', color='g', label='categ')
plt.grid=True
plt.tight_layout
#plt.legend('Installations', 'Category installations')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1232\1090811720.py in <module>
#       1 plt.style.use('fivethirtyeight')
# ----> 2 plt.bar(['Category','Installs'], color='b', label='instal')
#       3 plt.title("installations Graph")
#       4 plt.xlabel("Categories")
#       5 plt.ylabel("Installs")
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
df[['Category','Installs']]

# %%
plt.style.available

# %%
# Checking the App Prices
df[['Category','App','Type','Price']].query('Type=="Paid"').sort_values('Category')

# %%
# Checking the Category Totals
df[['App','Category','Type','Price']].query('Type=="Paid"').groupby(['Category'], sort=True)['Price'].agg('sum')

# %%
df[['App','Category','Type','Price']].query('Type=="Paid"') \
    .groupby(['Category'], sort=True)['Price'] \
    .agg('sum').plot(kind="bar", 
                     title='App Categories vs. Total Prices',
                     xlabel='App Categories',
                     ylabel='Category Total(USD)')

plt.show()

# %%
df.shape
# Out:
# (8197, 11)

# %%
df_1 = df.iloc[:1000,:]
df_2 = df.iloc[1000:,:]
print("Shape of new dataframes - {} , {}".format(df_1.shape, df_2.shape))
# Out:
# Shape of new dataframes - (1000, 11) , (7197, 11)

# %%
df_1
# Out:
#      Unnamed: 0                                                App  \
# 0             0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1             1  U Launcher Lite – FREE Live Cool Themes, Hide ...
# 2             2                              Sketch - Draw & Paint
# 3             3              Pixel Draw - Number Art Coloring Book
# 4             4                         Paper flowers instructions
# ..          ...                                                ...
# 995         995                       Brain Waves - Binaural Beats
# 996         996                       21-Day Meditation Experience
# 997         997                      Prana Breath: Calm & Meditate
# 998         998      Fabulous: Motivate Me! Meditate, Relax, Sleep
# 999         999                      7 Cups: Anxiety & Stress Chat
#
#                Category  Rating  Reviews   Size  Installs  Type  Price  \
# 0        ART_AND_DESIGN     4.1      159  19.00     10000  Free    0.0
# ...

# %%
df_2
# Out:
#       Unnamed: 0                                              App  \
# 1000        1000                    Calm - Meditate, Sleep, Relax
# 1001        1001                                 White Noise Lite
# 1002        1002                     Relax Melodies: Sleep Sounds
# 1003        1003  Stop, Breathe & Think: Meditation & Mindfulness
# 1004        1004                          Simple Habit Meditation
# ...          ...                                              ...
# 8192        8192                                    FR Calculator
# 8193        8193                                 Sya9a Maroc - FR
# 8194        8194                 Fr. Mike Schmitz Audio Teachings
# 8195        8195                    The SCP Foundation DB fr nn5n
# 8196        8196    iHoroscope - 2018 Daily Horoscope & Astrology
#
#                  Category  Rating  Reviews   Size  Installs  Type  Price  \
# 1000   HEALTH_AND_FITNESS     4.6   111455 -99.99   5000000  Free    0.0
# ...

# %%
df.head(2)
# Out:
#    Unnamed: 0                                                App  \
# 0           0     Photo Editor & Candy Camera & Grid & ScrapBook
# 1           1  U Launcher Lite – FREE Live Cool Themes, Hide ...
#
#          Category  Rating  Reviews  Size  Installs  Type  Price  \
# 0  ART_AND_DESIGN     4.1      159  19.0     10000  Free    0.0
# 1  ART_AND_DESIGN     4.7    87510   8.7   5000000  Free    0.0
#
#   Content Rating        Genres
# 0       Everyone  Art & Design
# 1       Everyone  Art & Design

# %%
import pickle 
import json

# %%
split_df = np.array_split(df, 4)

# %%
with open('split_df.pkl', 'wb') as pickleDataFrame:
    pickle.dump(split_df, pickleDataFrame)

# %%
with open('split_df.pkl', 'rb') as pickleDataFrame:
    unpickled = pickle.load(pickleDataFrame)
    
unpickled
# Out:
# [      Unnamed: 0                                                App  \
#  0              0     Photo Editor & Candy Camera & Grid & ScrapBook
#  1              1  U Launcher Lite – FREE Live Cool Themes, Hide ...
#  2              2                              Sketch - Draw & Paint
#  3              3              Pixel Draw - Number Art Coloring Book
#  4              4                         Paper flowers instructions
#  ...          ...                                                ...
#  2045        2045                          U + professional baseball
#  2046        2046                              Mackolik Live Results
#  2047        2047                           Mercato foot by Maxifoot
#  2048        2048                        MUTV - Manchester United TV
#  2049        2049                                         NBC Sports
#
#              Category  Rating  Reviews   Size  Installs  Type  Price  \
# ...

# %%
split_df
# Out:
# [      Unnamed: 0                                                App  \
#  0              0     Photo Editor & Candy Camera & Grid & ScrapBook
#  1              1  U Launcher Lite – FREE Live Cool Themes, Hide ...
#  2              2                              Sketch - Draw & Paint
#  3              3              Pixel Draw - Number Art Coloring Book
#  4              4                         Paper flowers instructions
#  ...          ...                                                ...
#  2045        2045                          U + professional baseball
#  2046        2046                              Mackolik Live Results
#  2047        2047                           Mercato foot by Maxifoot
#  2048        2048                        MUTV - Manchester United TV
#  2049        2049                                         NBC Sports
#
#              Category  Rating  Reviews   Size  Installs  Type  Price  \
# ...
